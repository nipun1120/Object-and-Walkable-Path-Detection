# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import sys
import time

# %%
# !git clone https://github.com/tensorflow/models.git
# !apt-get -qq install libprotobuf-java pro-compilertobuf
# !protoc ./models/research/object_detection/protos/string_int_label_map.proto --python_out=.
# !cp -R models/research/object_detection/ object_detection/
# !rm -rf models
import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile
from collections import defaultdict
from io import StringIO
import matplotlib.pyplot as plt
from PIL import Image
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as vis_util
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 58192, done.
# remote: Counting objects: 100% (524/524), done.
# remote: Compressing objects: 100% (238/238), done.
# remote: Total 58192 (delta 294), reused 497 (delta 281), pack-reused 57668
# Receiving objects: 100% (58192/58192), 573.11 MiB | 29.34 MiB/s, done.
# Resolving deltas: 100% (40292/40292), done.
# E: Unable to locate package pro-compilertobuf

# %%
from google.colab import files
def upload_files():
  from google.colab import files
  uploaded = files.upload()
  for k, v in uploaded.items():
    open(k, 'wb').write(v)
  return list(uploaded.keys())
upload_files()
# Out:
#      <input type="file" id="files-d37dbc48-5bca-4535-88ee-3829959f231d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d37dbc48-5bca-4535-88ee-3829959f231d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving WhatsApp Video 2021-06-03 at 12.09.33 PM.mp4 to WhatsApp Video 2021-06-03 at 12.09.33 PM.mp4
# ['WhatsApp Video 2021-06-03 at 12.09.33 PM.mp4']

# %%
MODEL_NAME = 'ssd_inception_v2_coco_2017_11_17'
# high accuracy but very slow
# MODEL_NAME = 'faster_rcnn_resnet101_coco_2017_11_08'
MODEL_FILE = MODEL_NAME + '.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/'
# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = MODEL_NAME + '/frozen_inference_graph.pb'
# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = os.path.join('object_detection/data', 'mscoco_label_map.pbtxt')
NUM_CLASSES = 4
opener = urllib.request.URLopener()
opener.retrieve(DOWNLOAD_BASE + MODEL_FILE, MODEL_FILE)
tar_file = tarfile.open(MODEL_FILE)
for file in tar_file.getmembers():
  file_name = os.path.basename(file.name)
  if 'frozen_inference_graph.pb' in file_name:
    tar_file.extract(file, os.getcwd())
    
detection_graph = tf.Graph()
with detection_graph.as_default():
  od_graph_def = tf.compat.v1.GraphDef()
  with tf.compat.v2.io.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
    serialized_graph = fid.read()
    od_graph_def.ParseFromString(serialized_graph)
    tf.import_graph_def(od_graph_def, name='')
    
label_map = label_map_util.load_labelmap(PATH_TO_LABELS)# all the labels will be printed
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES, use_display_name=True)
category_index = label_map_util.create_category_index(categories)

# %%
print(category_index)
# Out:
# {1: {'id': 1, 'name': 'person'}, 2: {'id': 2, 'name': 'bicycle'}, 3: {'id': 3, 'name': 'car'}, 4: {'id': 4, 'name': 'motorcycle'}}

# %%
print(categories)
# Out:
# [{'id': 1, 'name': 'person'}, {'id': 2, 'name': 'bicycle'}, {'id': 3, 'name': 'car'}, {'id': 4, 'name': 'motorcycle'}]

# %%
detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.compat.v1.GraphDef()
    with tf.compat.v2.io.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')
sess = tf.compat.v1.Session(graph=detection_graph)
# Define input and output tensors (i.e. data) for the object detection classifier
# Input tensor is the image
image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')
# Output tensors are the detection boxes, scores, and classes
# Each box represents a part of the image where a particular object was detected
detection_boxes = detection_graph.get_tensor_by_name('detection_boxes:0')
# Each score represents level of confidence for each of the objects.
# The score is shown on the result image, together with the class label.
detection_scores = detection_graph.get_tensor_by_name('detection_scores:0')
detection_classes = detection_graph.get_tensor_by_name('detection_classes:0')
# Number of objects detected
num_detections = detection_graph.get_tensor_by_name('num_detections:0')

# %%
def region_of_interest(img, vertices):
    mask = np.zeros_like(img)   
    if len(img.shape) > 2:
        channel_count = img.shape[2]
        # If an image is grayscale, the tuple returned contains only the number of rows and columns, so it is a good method to check whether the loaded image is grayscale or color.
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255   
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

# %%
video = cv2.VideoCapture("WhatsApp Video 2021-06-03 at 12.09.33 PM.mp4")
fourcc = cv2.VideoWriter_fourcc(*'XVID')  ##for recording, defining the codec
frame_width = int(video.get(3))
frame_height = int(video.get(4))
# out = cv2.VideoWriter('output.avi',fourcc, 20.0, (640,480))
# out = cv2.VideoWriter('outpy.mp4',cv2.VideoWriter_fourcc('M','J','P','G'), 20, (frame_width,frame_height))
out = cv2.VideoWriter('output_video.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 20 , (frame_width,frame_height))
try:
  
  while(video.isOpened()):

      ret, frame = video.read()
      stime = time.time()
      objects = []
      class_str = ""
      frame_width = frame.shape[0]
      frame_height = frame.shape[1]
      rows, cols = frame.shape[:2]
      left_boundary = [int(cols*0.40), int(rows*0.95)]
      left_boundary_top = [int(cols*0.40), int(rows*0.20)]
      right_boundary = [int(cols*0.60), int(rows*0.95)]
      right_boundary_top = [int(cols*0.60), int(rows*0.20)]
      bottom_left  = [int(cols*0.20), int(rows*0.95)]
      top_left     = [int(cols*0.20), int(rows*0.20)]
      bottom_right = [int(cols*0.80), int(rows*0.95)]
      top_right    = [int(cols*0.80), int(rows*0.20)]
      vertices = np.array([[bottom_left, top_left, top_right, bottom_right]], dtype=np.int32)
      cv2.line(frame,tuple(bottom_left),tuple(bottom_right), (255, 0, 0), 5)
      cv2.line(frame,tuple(bottom_right),tuple(top_right), (255, 0, 0), 5)
      cv2.line(frame,tuple(top_left),tuple(bottom_left), (255, 0, 0), 5)
      cv2.line(frame,tuple(top_left),tuple(top_right), (255, 0, 0), 5)
      copied = np.copy(frame)
      interested=region_of_interest(copied,vertices)
      frame_expanded = np.expand_dims(interested, axis=0) #1x2

      (boxes, scores, classes, num) = sess.run(
          [detection_boxes, detection_scores, detection_classes, num_detections],
          feed_dict={image_tensor: frame_expanded})
      # vis_util- printing names of the label on the top corner of the labelled box
      vis_util.visualize_boxes_and_labels_on_image_array(
          frame,
          np.squeeze(boxes),
          np.squeeze(classes).astype(np.int32),
          np.squeeze(scores),
          category_index,
          use_normalized_coordinates=True,
          line_thickness=8,
          min_score_thresh=0.78)
      print(frame_width,frame_height)
      ymin = int((boxes[0][0][0]*frame_width))
      xmin = int((boxes[0][0][1]*frame_height))
      ymax = int((boxes[0][0][2]*frame_width))
      xmax = int((boxes[0][0][3]*frame_height))
      Result = np.array(frame[ymin:ymax,xmin:xmax])

      ymin_str='y min  = %.2f '%(ymin)
      ymax_str='y max  = %.2f '%(ymax)
      xmin_str='x min  = %.2f '%(xmin)
      xmax_str='x max  = %.2f '%(xmax)

      cv2.putText(frame,ymin_str, (50, 50),cv2.FONT_HERSHEY_SIMPLEX,0.6,(255,0,0),2)
      cv2.putText(frame,ymax_str, (50, 70),cv2.FONT_HERSHEY_SIMPLEX,0.6,(255,0,0),2)
      cv2.putText(frame,xmin_str, (50, 90),cv2.FONT_HERSHEY_SIMPLEX,0.6,(255,0,0),2)
      cv2.putText(frame,xmax_str, (50, 110),cv2.FONT_HERSHEY_SIMPLEX,0.6,(255,0,0),2)
      print(scores.max())
     
      print("left_boundary[0],right_boundary[0] :", left_boundary[0], right_boundary[0])
      print("left_boundary[1],right_boundary[1] :", left_boundary[1], right_boundary[1])
      print("xmin, xmax :", xmin, xmax)
      print("ymin, ymax :", ymin, ymax)
      if scores.max() > 0.78:
         print("inif")
      if(xmin >= left_boundary[0]):
          print("move LEFT - 1st !!!")
          cv2.putText(frame,'Move LEFT!', (300, 100),cv2.FONT_HERSHEY_SIMPLEX,1.5,(0,255,0),2)
      elif(xmax <= right_boundary[0]):
          print("move Right - 2nd !!!")
          cv2.putText(frame,'Move RIGHT!', (300, 100),cv2.FONT_HERSHEY_SIMPLEX,1.5,(0,255,0),2)
      elif(xmin <= left_boundary[0] and xmax >= right_boundary[0]):
          print("STOPPPPPP !!!! - 3nd !!!")
          cv2.putText(frame,' STOPPPPPP!!!', (300, 100),cv2.FONT_HERSHEY_SIMPLEX,1.5,(0,255,0),2)
          cv2.line(frame,tuple(left_boundary),tuple(left_boundary_top), (255, 0, 0), 5)
      cv2.line(frame,tuple(right_boundary),tuple(right_boundary_top), (255, 0, 0), 5)
      out.write(frame)
except:
  pass
# Out:
# 352 640
# 0.5082807
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 123 531
# ymin, ymax : 72 327
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.5047065
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 121 512
# ymin, ymax : 67 316
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.3566528
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 125 540
# ymin, ymax : 74 324
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.34555483
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 128 543
# ymin, ymax : 75 320
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.27807748
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 467 506
# ymin, ymax : 135 262
# move LEFT - 1st !!!
# 352 640
# 0.1534262
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 466 507
# ymin, ymax : 134 263
# move LEFT - 1st !!!
# 352 640
# 0.17230156
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 328 466
# ymin, ymax : 106 318
# move LEFT - 1st !!!
# 352 640
# 0.19278613
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 328 469
# ymin, ymax : 105 316
# move LEFT - 1st !!!
# 352 640
# 0.14421657
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 332 454
# ymin, ymax : 220 330
# move LEFT - 1st !!!
# 352 640
# 0.30022472
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 468 506
# ymin, ymax : 133 264
# move LEFT - 1st !!!
# 352 640
# 0.41936225
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 467 505
# ymin, ymax : 135 265
# move LEFT - 1st !!!
# 352 640
# 0.42389864
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 467 504
# ymin, ymax : 134 266
# move LEFT - 1st !!!
# 352 640
# 0.39240605
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 465 504
# ymin, ymax : 135 266
# move LEFT - 1st !!!
# 352 640
# 0.43599406
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 463 503
# ymin, ymax : 134 266
# move LEFT - 1st !!!
# 352 640
# 0.3165344
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 462 503
# ymin, ymax : 134 265
# move LEFT - 1st !!!
# 352 640
# 0.3491812
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 463 504
# ymin, ymax : 135 265
# move LEFT - 1st !!!
# 352 640
# 0.27152067
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 464 506
# ymin, ymax : 137 265
# move LEFT - 1st !!!
# 352 640
# 0.19741628
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 335 451
# ymin, ymax : 219 330
# move LEFT - 1st !!!
# 352 640
# 0.2025705
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 465 506
# ymin, ymax : 137 265
# move LEFT - 1st !!!
# 352 640
# 0.3974929
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 467 505
# ymin, ymax : 136 265
# move LEFT - 1st !!!
# 352 640
# 0.28646976
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 466 505
# ymin, ymax : 135 268
# move LEFT - 1st !!!
# 352 640
# 0.3224827
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 465 504
# ymin, ymax : 136 269
# move LEFT - 1st !!!
# 352 640
# 0.37643704
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 468 504
# ymin, ymax : 135 269
# move LEFT - 1st !!!
# 352 640
# 0.27997613
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 469 506
# ymin, ymax : 137 267
# move LEFT - 1st !!!
# 352 640
# 0.42393973
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 469 505
# ymin, ymax : 135 270
# move LEFT - 1st !!!
# 352 640
# 0.27378446
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 471 507
# ymin, ymax : 137 268
# move LEFT - 1st !!!
# 352 640
# 0.3347609
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 471 507
# ymin, ymax : 136 269
# move LEFT - 1st !!!
# 352 640
# 0.34547096
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 475 508
# ymin, ymax : 135 269
# move LEFT - 1st !!!
# 352 640
# 0.43408793
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 477 507
# ymin, ymax : 134 271
# move LEFT - 1st !!!
# 352 640
# 0.35204566
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 476 507
# ymin, ymax : 136 268
# move LEFT - 1st !!!
# 352 640
# 0.63846385
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 124 516
# ymin, ymax : 73 296
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.34110945
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 340 461
# ymin, ymax : 218 328
# move LEFT - 1st !!!
# 352 640
# 0.4068764
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 123 517
# ymin, ymax : 72 321
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.24093011
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 342 469
# ymin, ymax : 173 322
# move LEFT - 1st !!!
# 352 640
# 0.24931112
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 344 465
# ymin, ymax : 219 328
# move LEFT - 1st !!!
# 352 640
# 0.3046952
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 126 528
# ymin, ymax : 69 317
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.13875851
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 343 466
# ymin, ymax : 212 330
# move LEFT - 1st !!!
# 352 640
# 0.15654102
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 126 513
# ymin, ymax : 72 332
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.22449023
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 344 468
# ymin, ymax : 214 330
# move LEFT - 1st !!!
# 352 640
# 0.18009222
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 342 478
# ymin, ymax : 219 328
# move LEFT - 1st !!!
# 352 640
# 0.45422062
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 339 487
# ymin, ymax : 92 332
# move LEFT - 1st !!!
# 352 640
# 0.6239574
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 117 525
# ymin, ymax : 62 311
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.29185325
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 344 488
# ymin, ymax : 100 328
# move LEFT - 1st !!!
# 352 640
# 0.3011542
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 344 469
# ymin, ymax : 225 329
# move LEFT - 1st !!!
# 352 640
# 0.15451574
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 342 469
# ymin, ymax : 226 330
# move LEFT - 1st !!!
# 352 640
# 0.26868707
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 347 486
# ymin, ymax : 99 330
# move LEFT - 1st !!!
# 352 640
# 0.27754784
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 346 484
# ymin, ymax : 93 329
# move LEFT - 1st !!!
# 352 640
# 0.1679976
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 340 469
# ymin, ymax : 228 331
# move LEFT - 1st !!!
# 352 640
# 0.21225142
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 340 490
# ymin, ymax : 90 316
# move LEFT - 1st !!!
# 352 640
# 0.5250778
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 339 471
# ymin, ymax : 228 331
# move LEFT - 1st !!!
# 352 640
# 0.2779348
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 337 470
# ymin, ymax : 226 331
# move LEFT - 1st !!!
# 352 640
# 0.23997214
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 126 501
# ymin, ymax : 68 312
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.4617538
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 338 489
# ymin, ymax : 94 315
# move LEFT - 1st !!!
# 352 640
# 0.5028488
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 129 532
# ymin, ymax : 74 327
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.59099305
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 118 512
# ymin, ymax : 68 318
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.32651007
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 340 470
# ymin, ymax : 225 330
# move LEFT - 1st !!!
# 352 640
# 0.21678561
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 341 469
# ymin, ymax : 223 329
# move LEFT - 1st !!!
# 352 640
# 0.22580892
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 122 518
# ymin, ymax : 72 322
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.15506971
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 123 520
# ymin, ymax : 71 321
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.2612974
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 123 522
# ymin, ymax : 72 319
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.11856431
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 133 540
# ymin, ymax : 76 314
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.16656998
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 137 541
# ymin, ymax : 75 315
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.19764191
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 127 545
# ymin, ymax : 77 315
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.1938585
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 128 542
# ymin, ymax : 70 321
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.18109798
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 132 547
# ymin, ymax : 73 306
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.22473603
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 347 495
# ymin, ymax : 82 325
# move LEFT - 1st !!!
# 352 640
# 0.3419006
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 336 504
# ymin, ymax : 74 317
# move LEFT - 1st !!!
# 352 640
# 0.22077078
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 137 529
# ymin, ymax : 75 305
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.2500807
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 130 520
# ymin, ymax : 72 317
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.22807887
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 335 508
# ymin, ymax : 72 320
# move LEFT - 1st !!!
# 352 640
# 0.22378328
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 337 504
# ymin, ymax : 77 319
# move LEFT - 1st !!!
# 352 640
# 0.122153044
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 338 512
# ymin, ymax : 69 319
# move LEFT - 1st !!!
# 352 640
# 0.19787642
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 136 532
# ymin, ymax : 72 314
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.38290936
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 342 502
# ymin, ymax : 84 331
# move LEFT - 1st !!!
# 352 640
# 0.3795156
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 124 522
# ymin, ymax : 68 317
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.48742408
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 130 524
# ymin, ymax : 72 319
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.3477032
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 179 371
# ymin, ymax : 167 278
# move Right - 2nd !!!
# 352 640
# 0.53414357
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 348 499
# ymin, ymax : 101 327
# move LEFT - 1st !!!
# 352 640
# 0.18983793
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 352 503
# ymin, ymax : 96 326
# move LEFT - 1st !!!
# 352 640
# 0.301125
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 168 390
# ymin, ymax : 167 291
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.34332168
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 163 388
# ymin, ymax : 165 290
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.20897478
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 356 503
# ymin, ymax : 94 326
# move LEFT - 1st !!!
# 352 640
# 0.1275709
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 166 367
# ymin, ymax : 167 296
# move Right - 2nd !!!
# 352 640
# 0.19604164
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 354 496
# ymin, ymax : 90 324
# move LEFT - 1st !!!
# 352 640
# 0.35269356
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 356 500
# ymin, ymax : 91 327
# move LEFT - 1st !!!
# 352 640
# 0.33200017
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 129 512
# ymin, ymax : 75 332
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.24317291
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 127 514
# ymin, ymax : 73 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.09252176
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 126 514
# ymin, ymax : 78 335
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.23842391
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 121 524
# ymin, ymax : 66 331
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.14752376
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 136 506
# ymin, ymax : 72 331
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.26354474
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 128 505
# ymin, ymax : 68 334
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.14694116
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 119 522
# ymin, ymax : 69 335
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.26552683
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 117 520
# ymin, ymax : 70 338
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.17363974
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 128 506
# ymin, ymax : 71 335
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.12798807
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 108 527
# ymin, ymax : 63 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.13098234
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 117 517
# ymin, ymax : 68 333
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.09225124
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 113 515
# ymin, ymax : 65 329
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.16229168
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 105 535
# ymin, ymax : 65 334
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.10646185
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 99 540
# ymin, ymax : 65 334
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.1759372
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 103 537
# ymin, ymax : 63 330
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.21793452
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 103 542
# ymin, ymax : 66 330
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.20313731
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 105 543
# ymin, ymax : 67 331
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.18209335
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 101 545
# ymin, ymax : 66 333
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.18832538
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 96 542
# ymin, ymax : 67 332
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.0674386
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 107 541
# ymin, ymax : 73 332
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.095968634
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 137 362
# ymin, ymax : 150 187
# move Right - 2nd !!!
# 352 640
# 0.10061851
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 115 534
# ymin, ymax : 69 335
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.2251043
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 115 529
# ymin, ymax : 69 335
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.15333155
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 117 518
# ymin, ymax : 72 337
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.15110862
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 114 526
# ymin, ymax : 70 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.22589806
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 114 526
# ymin, ymax : 70 335
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.13136375
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 113 545
# ymin, ymax : 68 338
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.1814934
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 114 543
# ymin, ymax : 68 337
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.5080493
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 115 531
# ymin, ymax : 70 333
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.28304017
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 116 539
# ymin, ymax : 69 333
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.07113877
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 354 503
# ymin, ymax : 73 137
# move LEFT - 1st !!!
# 352 640
# 0.07325512
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 346 500
# ymin, ymax : 72 139
# move LEFT - 1st !!!
# 352 640
# 0.06052643
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 395 453
# ymin, ymax : 151 271
# move LEFT - 1st !!!
# 352 640
# 0.061307907
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 123 519
# ymin, ymax : 70 337
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.076304555
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 100 553
# ymin, ymax : 65 338
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.08755955
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 111 551
# ymin, ymax : 60 341
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.11104676
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 108 553
# ymin, ymax : 58 337
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.07434502
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 124 522
# ymin, ymax : 71 340
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.056754977
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 216 377
# ymin, ymax : 152 195
# move Right - 2nd !!!
# 352 640
# 0.06078756
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 389 494
# ymin, ymax : 207 319
# move LEFT - 1st !!!
# 352 640
# 0.049333066
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 174 381
# ymin, ymax : 150 197
# move Right - 2nd !!!
# 352 640
# 0.071020246
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 93 564
# ymin, ymax : 63 337
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.08297774
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 91 559
# ymin, ymax : 62 335
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.12312406
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 87 565
# ymin, ymax : 62 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.069984734
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 237 337
# ymin, ymax : 91 172
# move Right - 2nd !!!
# 352 640
# 0.057430893
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 269 372
# ymin, ymax : 226 310
# move LEFT - 1st !!!
# 352 640
# 0.07049441
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 242 336
# ymin, ymax : 140 170
# move Right - 2nd !!!
# 352 640
# 0.07594335
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 246 339
# ymin, ymax : 141 169
# move Right - 2nd !!!
# 352 640
# 0.08876479
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 249 340
# ymin, ymax : 142 169
# move Right - 2nd !!!
# 352 640
# 0.11073479
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 254 342
# ymin, ymax : 141 168
# move Right - 2nd !!!
# 352 640
# 0.10053033
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 100 548
# ymin, ymax : 78 333
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.10465142
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 174 391
# ymin, ymax : 158 197
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.083317906
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 188 389
# ymin, ymax : 155 197
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.06530383
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 363 501
# ymin, ymax : 128 185
# move LEFT - 1st !!!
# 352 640
# 0.07856846
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 196 413
# ymin, ymax : 155 195
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.08136335
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 152 258
# ymin, ymax : 81 183
# move Right - 2nd !!!
# 352 640
# 0.094790876
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 195 427
# ymin, ymax : 166 204
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.1687198
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 275 365
# ymin, ymax : 142 168
# move LEFT - 1st !!!
# 352 640
# 0.45592234
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 107 542
# ymin, ymax : 78 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.6714334
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 106 537
# ymin, ymax : 76 333
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.7832246
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 110 527
# ymin, ymax : 78 334
# inif
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.90306836
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 117 523
# ymin, ymax : 72 332
# inif
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.47472143
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 117 523
# ymin, ymax : 76 340
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.5338543
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 107 523
# ymin, ymax : 73 334
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.43323964
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 115 523
# ymin, ymax : 68 335
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.29785854
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 121 521
# ymin, ymax : 67 330
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.27578753
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 117 527
# ymin, ymax : 64 329
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.8984312
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 126 514
# ymin, ymax : 85 337
# inif
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.93366015
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 120 523
# ymin, ymax : 77 336
# inif
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.8853396
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 124 524
# ymin, ymax : 66 334
# inif
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.58902377
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 123 517
# ymin, ymax : 78 338
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.46795565
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 126 510
# ymin, ymax : 96 335
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.14645386
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 318 394
# ymin, ymax : 239 320
# move LEFT - 1st !!!
# 352 640
# 0.18515053
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 438 488
# ymin, ymax : 209 325
# move LEFT - 1st !!!
# 352 640
# 0.12438232
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 434 490
# ymin, ymax : 210 325
# move LEFT - 1st !!!
# 352 640
# 0.1424923
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 210 291
# ymin, ymax : 80 170
# move Right - 2nd !!!
# 352 640
# 0.103008896
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 170 268
# ymin, ymax : 81 191
# move Right - 2nd !!!
# 352 640
# 0.09119794
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 216 289
# ymin, ymax : 77 170
# move Right - 2nd !!!
# 352 640
# 0.14155519
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 450 504
# ymin, ymax : 213 325
# move LEFT - 1st !!!
# 352 640
# 0.14911234
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 449 506
# ymin, ymax : 214 326
# move LEFT - 1st !!!
# 352 640
# 0.1576876
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 115 517
# ymin, ymax : 67 330
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.32185417
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 105 531
# ymin, ymax : 75 318
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.15221217
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 448 508
# ymin, ymax : 215 325
# move LEFT - 1st !!!
# 352 640
# 0.1080935
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 449 508
# ymin, ymax : 215 324
# move LEFT - 1st !!!
# 352 640
# 0.0996955
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 449 508
# ymin, ymax : 215 324
# move LEFT - 1st !!!
# 352 640
# 0.210926
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 125 511
# ymin, ymax : 100 334
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.0791384
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 121 513
# ymin, ymax : 93 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.36742282
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 445 506
# ymin, ymax : 212 328
# move LEFT - 1st !!!
# 352 640
# 0.2675351
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 446 504
# ymin, ymax : 214 326
# move LEFT - 1st !!!
# 352 640
# 0.21501592
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 81 540
# ymin, ymax : 61 330
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.12378028
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 447 510
# ymin, ymax : 214 325
# move LEFT - 1st !!!
# 352 640
# 0.14454192
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 130 504
# ymin, ymax : 70 228
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.21957761
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 127 508
# ymin, ymax : 69 224
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.5528967
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 119 515
# ymin, ymax : 64 290
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.33115995
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 129 510
# ymin, ymax : 69 230
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.2042495
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 107 520
# ymin, ymax : 70 327
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.5299864
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 114 519
# ymin, ymax : 62 330
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.37040797
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 115 517
# ymin, ymax : 62 327
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.43904212
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 118 517
# ymin, ymax : 62 297
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.6355909
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 120 517
# ymin, ymax : 63 292
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.3917206
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 121 510
# ymin, ymax : 68 241
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.5883989
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 117 507
# ymin, ymax : 62 300
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.7266639
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 120 506
# ymin, ymax : 64 282
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.43754068
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 110 515
# ymin, ymax : 57 324
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.4183445
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 112 508
# ymin, ymax : 59 292
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.6954483
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 126 510
# ymin, ymax : 64 305
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.6933457
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 118 517
# ymin, ymax : 64 300
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.5439736
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 122 514
# ymin, ymax : 65 283
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.6892712
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 123 509
# ymin, ymax : 67 315
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.19531885
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 100 537
# ymin, ymax : 65 329
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.097755015
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 91 536
# ymin, ymax : 65 328
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.14962545
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 108 524
# ymin, ymax : 68 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.22772118
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 106 521
# ymin, ymax : 66 338
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.43748283
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 112 526
# ymin, ymax : 64 338
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.49506038
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 111 521
# ymin, ymax : 66 337
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.2535218
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 104 528
# ymin, ymax : 60 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.34966695
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 115 522
# ymin, ymax : 66 339
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.51052564
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 115 520
# ymin, ymax : 66 340
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.8043879
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 114 516
# ymin, ymax : 66 340
# inif
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.47407377
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 114 518
# ymin, ymax : 65 342
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.58793485
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 114 518
# ymin, ymax : 65 341
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.42467391
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 106 529
# ymin, ymax : 62 339
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.40809554
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 111 518
# ymin, ymax : 64 340
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.6741687
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 116 514
# ymin, ymax : 64 339
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.42637995
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 112 524
# ymin, ymax : 63 339
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.4956992
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 110 524
# ymin, ymax : 63 338
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.35670388
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 111 527
# ymin, ymax : 63 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.59278536
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 111 531
# ymin, ymax : 62 339
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.6053836
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 112 532
# ymin, ymax : 61 338
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.61632645
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 112 531
# ymin, ymax : 62 338
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.6581804
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 112 530
# ymin, ymax : 61 338
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.58658457
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 114 530
# ymin, ymax : 60 337
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.67929745
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 114 529
# ymin, ymax : 60 337
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.52279425
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 121 531
# ymin, ymax : 60 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.2395812
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 106 535
# ymin, ymax : 57 336
# STOPPPPPP !!!! - 3nd !!!
# 352 640
# 0.32040918
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 299 401
# ymin, ymax : 96 272
# move LEFT - 1st !!!
# 352 640
# 0.42655262
# left_boundary[0],right_boundary[0] : 256 384
# left_boundary[1],right_boundary[1] : 334 334
# xmin, xmax : 152 273
# ymin, ymax : 89 261
# move Right - 2nd !!!
